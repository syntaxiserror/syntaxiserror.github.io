# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
env = gym.make("CarRacing-v2", render_mode="human")

# %%
for episode in range(1, 6):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info, _ = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# C:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=40000)
# Out:
# Logging to Training\Logs\PPO_8
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -54.6    |
# | time/              |          |
# |    fps             | 14       |
# |    iterations      | 1        |
# |    time_elapsed    | 143      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.6       |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 2           |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005444265 |
# |    clip_fraction        | 0.0612      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.00238     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.386       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00598    |
# |    std                  | 0.985       |
# |    value_loss           | 0.765       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 3           |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007630499 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.058       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.277       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.977       |
# |    value_loss           | 0.588       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.4       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 4           |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009445211 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.096       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.168       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.967       |
# |    value_loss           | 0.611       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.4       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 5           |
# |    time_elapsed         | 673         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011890627 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.268       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.955       |
# |    value_loss           | 0.576       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46.5       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 6           |
# |    time_elapsed         | 812         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010924009 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0251      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.951       |
# |    value_loss           | 0.36        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -45.1      |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 7          |
# |    time_elapsed         | 952        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01200183 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.09      |
# |    explained_variance   | 0.307      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.101      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0175    |
# |    std                  | 0.944      |
# |    value_loss           | 0.484      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.2       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 8           |
# |    time_elapsed         | 1089        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012084784 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0764      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.942       |
# |    value_loss           | 0.329       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.3       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 9           |
# |    time_elapsed         | 1226        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011996869 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0916      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.926       |
# |    value_loss           | 0.408       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.1       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 10          |
# |    time_elapsed         | 1358        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014055087 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | -0.0984     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.915       |
# |    value_loss           | 0.241       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.9       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 11          |
# |    time_elapsed         | 1489        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012905018 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.014       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.909       |
# |    value_loss           | 0.189       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.9       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 12          |
# |    time_elapsed         | 1622        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012863143 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0402      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.893       |
# |    value_loss           | 0.177       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.4       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 13          |
# |    time_elapsed         | 1764        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014091231 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0461      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.888       |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.6       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 14          |
# |    time_elapsed         | 1897        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019305602 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0329     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.884       |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 15          |
# |    time_elapsed         | 2044        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012453398 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.865       |
# |    value_loss           | 0.123       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -55.7       |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 16          |
# |    time_elapsed         | 2196        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011417459 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.858       |
# |    value_loss           | 0.132       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -56.5      |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 17         |
# |    time_elapsed         | 2339       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01724539 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.77      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00763   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0145    |
# |    std                  | 0.845      |
# |    value_loss           | 0.0841     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -56.2      |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 18         |
# |    time_elapsed         | 2507       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02210942 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.75      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0178    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0248    |
# |    std                  | 0.845      |
# |    value_loss           | 0.112      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -56.3       |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 19          |
# |    time_elapsed         | 2700        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017248452 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.833       |
# |    value_loss           | 0.166       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -56.3       |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 20          |
# |    time_elapsed         | 2885        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014086954 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.821       |
# |    value_loss           | 0.081       |
# -----------------------------------------

# %%
model_path = os.path.join("Training", "Car_Models", "Car")
model.save(model_path)

# %%
model = PPO.load(model_path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (5.854654478281736, 84.07127376710318)
